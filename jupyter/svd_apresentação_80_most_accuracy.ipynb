# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import time

from threading import Thread
from threading import Lock

import multiprocessing

from sklearn.model_selection import train_test_split 

from src.Images import preprocess_images_from_dir
from src.Images import get_all_images_path
from src.Images import read_processed_image
from src.Images import plot_image
from src.Images import flatten_to_image

from src.Distances import euclidean_distance
from src.Distances import cosine_distance

from src.Knn import Knn

from src.Settings import *

from src.Parallel import thread_classify_function
from src.Parallel import split_data_into_chunks
from src.Parallel import presentation_thread_classify_function

print_all_settings()
# Out:
# USE_NUMPY_ARRAY: True
# N_ROWS: 80
# N_COLUMNS: 80
# PREPROCESS_IMAGES: True
# N_THREADS: 4
# N_TESTS_USED: 200
# WORKSPACE: .
# DATASET_DIR: ./dataset
# IMAGES_DIR: ./dataset/dataset
# PROCESSED_IMAGES_PATH: ./dataset/dataset/_processed

# %%
def extract_class_from_path(path):
    return int(path.split(" ")[0].split("/")[-1])

def read_processed_image_to_numpy_array(path):
    return read_processed_image(path, GlobalSettings.N_ROWS, GlobalSettings.N_COLUMNS).flatten().reshape(-1,1)

def calculate_accumulated_variability(s, i):
    return 100*(np.sum(s[0:i])/np.sum(s))

def make_matrix_with_images_in_path(list_of_paths):
    return np.hstack([read_processed_image_to_numpy_array(path) for path in list_of_paths])

def centralize_matrix(matrix, mean_vector=None):
    if mean_vector is None:
        mean_vector = np.mean(matrix, axis=1, keepdims=True)
        
    centralized_data_matrix = matrix - mean_vector
    return centralized_data_matrix, mean_vector

def get_first_n_components(u, n):
    return u[:, :n]

def get_r_number_from_accumulated_variability(variability, s):
    r = 1
    
    while True:
        acc = calculate_accumulated_variability(s,r)
        if acc >= variability:
            return r
        else:
            r += 1

def perform_multiple_runs_to_create_graph(min_var, max_var, step):
    ACERTOS = []
    ERROS = []
    TAXA_ACERTOS = []
    VARIABILIDADE_ACUMULADA = []
    EIGENBLOCKS = []
    
    for r in range(get_r_number_from_accumulated_variability(min_var, s), get_r_number_from_accumulated_variability(max_var, s), step):
        U_r = get_first_n_components(u, r)
    
        x_train_projected = U_r.T @ x_train_centralized
        
        x_test_projected = U_r.T @ x_test_centralized
        
        acertos = 0
        erros = 0
        
        for i in range(GlobalSettings.N_TESTS_USED):
            test_img_proj = x_test_projected[:, i]
            
            distances = np.linalg.norm(x_train_projected.T - test_img_proj, axis=1)
            
            # Find the nearest training sample
            nearest_index = np.argmin(distances)
            
            # Compare the class label of the nearest training sample to the test sample's label
            if y_test[i] == y_train[nearest_index]:
                acertos += 1
            else:
                erros += 1
                
        total = acertos+erros
    
        ACERTOS.append(acertos)
        ERROS.append(erros)
        TAXA_ACERTOS.append(100*(acertos/total))
        VARIABILIDADE_ACUMULADA.append(calculate_accumulated_variability(s,r))
        EIGENBLOCKS.append(r)
    
    acertos = np.array(ACERTOS)
    erros = np.array(ERROS)
    taxaAcerto = np.array(TAXA_ACERTOS)
    variabilidadeAcumulada = np.array(VARIABILIDADE_ACUMULADA)
    num_eigenblocks = np.array(EIGENBLOCKS)
    
    plt.figure(figsize=(8,5))
    plt.plot(variabilidadeAcumulada,taxaAcerto,lw=3.0)
    plt.grid()
    plt.ylabel("Acurácia (%)")
    plt.xlabel("Variabilidade Acumulada (%)")
    plt.show()
    
    
    plt.figure(figsize=(8,5))
    plt.plot(variabilidadeAcumulada, taxaAcerto, lw=3.0, marker='o')
    
    # Add annotations for each point
    for x, y, n in zip(variabilidadeAcumulada, taxaAcerto, num_eigenblocks):
        plt.annotate(f'{n}', (x, y), textcoords="offset points", xytext=(0,10), ha='center')
    
    plt.grid()
    plt.ylabel("Acurácia (%)")
    plt.xlabel("Variabilidade Acumulada (%)")
    plt.title("Acurácia vs Variabilidade Acumulada with Eigenblocks")
    plt.show()

# %% [markdown]
# ## Preprocessamento das imagens

# %%
if GlobalSettings.PREPROCESS_IMAGES:
    ans = input("Are you sure you want to preprocess all images? [type 'yes']")
    if ans == "yes":
        preprocess_images_from_dir(
            dir_path=GlobalSettings.IMAGES_DIR, n_rows=GlobalSettings.N_ROWS,
            n_columns=GlobalSettings.N_COLUMNS, extension="png"
        )
# Out:
# Are you sure you want to preprocess all images? [type 'yes'] yes
# Found 40000 image(s)
# Directory ./dataset/dataset/_processed removed
# Writing images...
# Finished!

# %% [markdown]
# ## Paths para as imagens preprocessadas

# %%
images_path = get_all_images_path(GlobalSettings.PROCESSED_IMAGES_PATH)
images_path[:3]
# Out:
# ['./dataset/dataset/_processed/14719 flat tile corner 2x2 000L.png',
#  './dataset/dataset/_processed/14719 flat tile corner 2x2 000R.png',
#  './dataset/dataset/_processed/14719 flat tile corner 2x2 001L.png']

# %%
data = [
    (
        extract_class_from_path(path),
        path,
    ) for path in images_path
]

# %%
y, x = zip(*data)
x = list(x)
y = list(y)

# %%
x_train_paths, x_test_paths, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, shuffle=True)

# %%
x_train = make_matrix_with_images_in_path(x_train_paths)
print("x_train.shape:", x_train.shape)

x_test = make_matrix_with_images_in_path(x_test_paths)
print("x_test.shape:", x_test.shape)
# Out:
# x_train.shape: (6400, 28000)
# x_test.shape: (6400, 12000)

# %%
x_train_centralized, features_mean = centralize_matrix(x_train)
print("x_train_centralized.shape:", x_train_centralized.shape)

x_test_centralized, _ = centralize_matrix(x_test, features_mean)
print("x_test_centralized.shape:" ,x_test_centralized.shape)
# Out:
# x_train_centralized.shape: (6400, 28000)
# x_test_centralized.shape: (6400, 12000)

# %%
u, s, vt = np.linalg.svd(x_train_centralized,full_matrices=False)

print("Dimensões de u:", u.shape)
print("Dimensões de s:", s.shape)
print("Dimensões de vt:", vt.shape)
# Out:
# Dimensões de u: (6400, 6400)
# Dimensões de s: (6400,)
# Dimensões de vt: (6400, 28000)

# %%
for i in range(5):
    img = u[:, i].reshape(GlobalSettings.N_ROWS, GlobalSettings.N_COLUMNS)
    plot_image(img)

# %%
eigen = np.array([0])
acc = np.array([0])
for i in range(0,len(s),10):
    acc = np.hstack((acc,100*(np.sum(s[0:i])/np.sum(s))))
    eigen = np.hstack((eigen,i))
    print("Vetores singulares (eigenfaces):", i, "- Variabilidade acumulada: {:.2f}%".format(calculate_accumulated_variability(s,i)))
# Out:
# Vetores singulares (eigenfaces): 0 - Variabilidade acumulada: 0.00%
# Vetores singulares (eigenfaces): 10 - Variabilidade acumulada: 9.09%
# Vetores singulares (eigenfaces): 20 - Variabilidade acumulada: 13.00%
# Vetores singulares (eigenfaces): 30 - Variabilidade acumulada: 15.83%
# Vetores singulares (eigenfaces): 40 - Variabilidade acumulada: 18.09%
# Vetores singulares (eigenfaces): 50 - Variabilidade acumulada: 20.00%
# Vetores singulares (eigenfaces): 60 - Variabilidade acumulada: 21.72%
# Vetores singulares (eigenfaces): 70 - Variabilidade acumulada: 23.22%
# Vetores singulares (eigenfaces): 80 - Variabilidade acumulada: 24.56%
# Vetores singulares (eigenfaces): 90 - Variabilidade acumulada: 25.79%
# Vetores singulares (eigenfaces): 100 - Variabilidade acumulada: 26.91%
# Vetores singulares (eigenfaces): 110 - Variabilidade acumulada: 27.96%
# Vetores singulares (eigenfaces): 120 - Variabilidade acumulada: 28.95%
# Vetores singulares (eigenfaces): 130 - Variabilidade acumulada: 29.88%
# Vetores singulares (eigenfaces): 140 - Variabilidade acumulada: 30.78%
# Vetores singulares (eigenfaces): 150 - Variabilidade acumulada: 31.63%
# Vetores singulares (eigenfaces): 160 - Variabilidade acumulada: 32.44%
# Vetores singulares (eigenfaces): 170 - Variabilidade acumulada: 33.22%
# Vetores singulares (eigenfaces): 180 - Variabilidade acumulada: 33.96%
# Vetores singulares (eigenfaces): 190 - Variabilidade acumulada: 34.68%
# Vetores singulares (eigenfaces): 200 - Variabilidade acumulada: 35.36%
# Vetores singulares (eigenfaces): 210 - Variabilidade acumulada: 36.02%
# Vetores singulares (eigenfaces): 220 - Variabilidade acumulada: 36.66%
# Vetores singulares (eigenfaces): 230 - Variabilidade acumulada: 37.28%
# Vetores singulares (eigenfaces): 240 - Variabilidade acumulada: 37.89%
# Vetores singulares (eigenfaces): 250 - Variabilidade acumulada: 38.47%
# Vetores singulares (eigenfaces): 260 - Variabilidade acumulada: 39.04%
# Vetores singulares (eigenfaces): 270 - Variabilidade acumulada: 39.59%
# Vetores singulares (eigenfaces): 280 - Variabilidade acumulada: 40.13%
# Vetores singulares (eigenfaces): 290 - Variabilidade acumulada: 40.66%
# Vetores singulares (eigenfaces): 300 - Variabilidade acumulada: 41.17%
# Vetores singulares (eigenfaces): 310 - Variabilidade acumulada: 41.67%
# Vetores singulares (eigenfaces): 320 - Variabilidade acumulada: 42.16%
# Vetores singulares (eigenfaces): 330 - Variabilidade acumulada: 42.64%
# Vetores singulares (eigenfaces): 340 - Variabilidade acumulada: 43.11%
# Vetores singulares (eigenfaces): 350 - Variabilidade acumulada: 43.57%
# Vetores singulares (eigenfaces): 360 - Variabilidade acumulada: 44.02%
# Vetores singulares (eigenfaces): 370 - Variabilidade acumulada: 44.46%
# Vetores singulares (eigenfaces): 380 - Variabilidade acumulada: 44.90%
# Vetores singulares (eigenfaces): 390 - Variabilidade acumulada: 45.32%
# Vetores singulares (eigenfaces): 400 - Variabilidade acumulada: 45.74%
# Vetores singulares (eigenfaces): 410 - Variabilidade acumulada: 46.15%
# Vetores singulares (eigenfaces): 420 - Variabilidade acumulada: 46.55%
# Vetores singulares (eigenfaces): 430 - Variabilidade acumulada: 46.95%
# Vetores singulares (eigenfaces): 440 - Variabilidade acumulada: 47.34%
# Vetores singulares (eigenfaces): 450 - Variabilidade acumulada: 47.72%
# Vetores singulares (eigenfaces): 460 - Variabilidade acumulada: 48.10%
# Vetores singulares (eigenfaces): 470 - Variabilidade acumulada: 48.47%
# Vetores singulares (eigenfaces): 480 - Variabilidade acumulada: 48.83%
# Vetores singulares (eigenfaces): 490 - Variabilidade acumulada: 49.19%
# Vetores singulares (eigenfaces): 500 - Variabilidade acumulada: 49.55%
# Vetores singulares (eigenfaces): 510 - Variabilidade acumulada: 49.90%
# Vetores singulares (eigenfaces): 520 - Variabilidade acumulada: 50.24%
# Vetores singulares (eigenfaces): 530 - Variabilidade acumulada: 50.58%
# Vetores singulares (eigenfaces): 540 - Variabilidade acumulada: 50.92%
# Vetores singulares (eigenfaces): 550 - Variabilidade acumulada: 51.25%
# Vetores singulares (eigenfaces): 560 - Variabilidade acumulada: 51.58%
# Vetores singulares (eigenfaces): 570 - Variabilidade acumulada: 51.90%
# Vetores singulares (eigenfaces): 580 - Variabilidade acumulada: 52.22%
# Vetores singulares (eigenfaces): 590 - Variabilidade acumulada: 52.54%
# Vetores singulares (eigenfaces): 600 - Variabilidade acumulada: 52.85%
# Vetores singulares (eigenfaces): 610 - Variabilidade acumulada: 53.16%
# Vetores singulares (eigenfaces): 620 - Variabilidade acumulada: 53.46%
# Vetores singulares (eigenfaces): 630 - Variabilidade acumulada: 53.76%
# Vetores singulares (eigenfaces): 640 - Variabilidade acumulada: 54.06%
# Vetores singulares (eigenfaces): 650 - Variabilidade acumulada: 54.36%
# Vetores singulares (eigenfaces): 660 - Variabilidade acumulada: 54.65%
# Vetores singulares (eigenfaces): 670 - Variabilidade acumulada: 54.94%
# Vetores singulares (eigenfaces): 680 - Variabilidade acumulada: 55.22%
# Vetores singulares (eigenfaces): 690 - Variabilidade acumulada: 55.51%
# Vetores singulares (eigenfaces): 700 - Variabilidade acumulada: 55.79%
# Vetores singulares (eigenfaces): 710 - Variabilidade acumulada: 56.07%
# Vetores singulares (eigenfaces): 720 - Variabilidade acumulada: 56.34%
# Vetores singulares (eigenfaces): 730 - Variabilidade acumulada: 56.61%
# Vetores singulares (eigenfaces): 740 - Variabilidade acumulada: 56.88%
# Vetores singulares (eigenfaces): 750 - Variabilidade acumulada: 57.15%
# Vetores singulares (eigenfaces): 760 - Variabilidade acumulada: 57.42%
# Vetores singulares (eigenfaces): 770 - Variabilidade acumulada: 57.68%
# Vetores singulares (eigenfaces): 780 - Variabilidade acumulada: 57.94%
# Vetores singulares (eigenfaces): 790 - Variabilidade acumulada: 58.20%
# Vetores singulares (eigenfaces): 800 - Variabilidade acumulada: 58.46%
# Vetores singulares (eigenfaces): 810 - Variabilidade acumulada: 58.71%
# Vetores singulares (eigenfaces): 820 - Variabilidade acumulada: 58.96%
# Vetores singulares (eigenfaces): 830 - Variabilidade acumulada: 59.21%
# Vetores singulares (eigenfaces): 840 - Variabilidade acumulada: 59.46%
# Vetores singulares (eigenfaces): 850 - Variabilidade acumulada: 59.71%
# Vetores singulares (eigenfaces): 860 - Variabilidade acumulada: 59.96%
# Vetores singulares (eigenfaces): 870 - Variabilidade acumulada: 60.20%
# Vetores singulares (eigenfaces): 880 - Variabilidade acumulada: 60.44%
# Vetores singulares (eigenfaces): 890 - Variabilidade acumulada: 60.68%
# Vetores singulares (eigenfaces): 900 - Variabilidade acumulada: 60.92%
# Vetores singulares (eigenfaces): 910 - Variabilidade acumulada: 61.16%
# Vetores singulares (eigenfaces): 920 - Variabilidade acumulada: 61.39%
# Vetores singulares (eigenfaces): 930 - Variabilidade acumulada: 61.62%
# Vetores singulares (eigenfaces): 940 - Variabilidade acumulada: 61.86%
# Vetores singulares (eigenfaces): 950 - Variabilidade acumulada: 62.09%
# Vetores singulares (eigenfaces): 960 - Variabilidade acumulada: 62.32%
# Vetores singulares (eigenfaces): 970 - Variabilidade acumulada: 62.54%
# Vetores singulares (eigenfaces): 980 - Variabilidade acumulada: 62.77%
# Vetores singulares (eigenfaces): 990 - Variabilidade acumulada: 62.99%
# Vetores singulares (eigenfaces): 1000 - Variabilidade acumulada: 63.22%
# Vetores singulares (eigenfaces): 1010 - Variabilidade acumulada: 63.44%
# Vetores singulares (eigenfaces): 1020 - Variabilidade acumulada: 63.66%
# Vetores singulares (eigenfaces): 1030 - Variabilidade acumulada: 63.88%
# Vetores singulares (eigenfaces): 1040 - Variabilidade acumulada: 64.10%
# Vetores singulares (eigenfaces): 1050 - Variabilidade acumulada: 64.32%
# Vetores singulares (eigenfaces): 1060 - Variabilidade acumulada: 64.53%
# Vetores singulares (eigenfaces): 1070 - Variabilidade acumulada: 64.75%
# Vetores singulares (eigenfaces): 1080 - Variabilidade acumulada: 64.96%
# Vetores singulares (eigenfaces): 1090 - Variabilidade acumulada: 65.17%
# Vetores singulares (eigenfaces): 1100 - Variabilidade acumulada: 65.38%
# Vetores singulares (eigenfaces): 1110 - Variabilidade acumulada: 65.59%
# Vetores singulares (eigenfaces): 1120 - Variabilidade acumulada: 65.80%
# Vetores singulares (eigenfaces): 1130 - Variabilidade acumulada: 66.01%
# Vetores singulares (eigenfaces): 1140 - Variabilidade acumulada: 66.21%
# Vetores singulares (eigenfaces): 1150 - Variabilidade acumulada: 66.42%
# Vetores singulares (eigenfaces): 1160 - Variabilidade acumulada: 66.62%
# Vetores singulares (eigenfaces): 1170 - Variabilidade acumulada: 66.82%
# Vetores singulares (eigenfaces): 1180 - Variabilidade acumulada: 67.02%
# Vetores singulares (eigenfaces): 1190 - Variabilidade acumulada: 67.22%
# Vetores singulares (eigenfaces): 1200 - Variabilidade acumulada: 67.42%
# Vetores singulares (eigenfaces): 1210 - Variabilidade acumulada: 67.62%
# Vetores singulares (eigenfaces): 1220 - Variabilidade acumulada: 67.82%
# Vetores singulares (eigenfaces): 1230 - Variabilidade acumulada: 68.02%
# Vetores singulares (eigenfaces): 1240 - Variabilidade acumulada: 68.21%
# Vetores singulares (eigenfaces): 1250 - Variabilidade acumulada: 68.41%
# Vetores singulares (eigenfaces): 1260 - Variabilidade acumulada: 68.60%
# Vetores singulares (eigenfaces): 1270 - Variabilidade acumulada: 68.79%
# Vetores singulares (eigenfaces): 1280 - Variabilidade acumulada: 68.98%
# Vetores singulares (eigenfaces): 1290 - Variabilidade acumulada: 69.17%
# Vetores singulares (eigenfaces): 1300 - Variabilidade acumulada: 69.36%
# Vetores singulares (eigenfaces): 1310 - Variabilidade acumulada: 69.55%
# Vetores singulares (eigenfaces): 1320 - Variabilidade acumulada: 69.74%
# Vetores singulares (eigenfaces): 1330 - Variabilidade acumulada: 69.92%
# Vetores singulares (eigenfaces): 1340 - Variabilidade acumulada: 70.11%
# Vetores singulares (eigenfaces): 1350 - Variabilidade acumulada: 70.29%
# Vetores singulares (eigenfaces): 1360 - Variabilidade acumulada: 70.48%
# Vetores singulares (eigenfaces): 1370 - Variabilidade acumulada: 70.66%
# Vetores singulares (eigenfaces): 1380 - Variabilidade acumulada: 70.84%
# Vetores singulares (eigenfaces): 1390 - Variabilidade acumulada: 71.02%
# Vetores singulares (eigenfaces): 1400 - Variabilidade acumulada: 71.20%
# Vetores singulares (eigenfaces): 1410 - Variabilidade acumulada: 71.38%
# Vetores singulares (eigenfaces): 1420 - Variabilidade acumulada: 71.56%
# Vetores singulares (eigenfaces): 1430 - Variabilidade acumulada: 71.74%
# Vetores singulares (eigenfaces): 1440 - Variabilidade acumulada: 71.92%
# Vetores singulares (eigenfaces): 1450 - Variabilidade acumulada: 72.09%
# Vetores singulares (eigenfaces): 1460 - Variabilidade acumulada: 72.27%
# Vetores singulares (eigenfaces): 1470 - Variabilidade acumulada: 72.44%
# Vetores singulares (eigenfaces): 1480 - Variabilidade acumulada: 72.62%
# Vetores singulares (eigenfaces): 1490 - Variabilidade acumulada: 72.79%
# Vetores singulares (eigenfaces): 1500 - Variabilidade acumulada: 72.96%
# Vetores singulares (eigenfaces): 1510 - Variabilidade acumulada: 73.13%
# Vetores singulares (eigenfaces): 1520 - Variabilidade acumulada: 73.30%
# Vetores singulares (eigenfaces): 1530 - Variabilidade acumulada: 73.47%
# Vetores singulares (eigenfaces): 1540 - Variabilidade acumulada: 73.64%
# Vetores singulares (eigenfaces): 1550 - Variabilidade acumulada: 73.81%
# Vetores singulares (eigenfaces): 1560 - Variabilidade acumulada: 73.98%
# Vetores singulares (eigenfaces): 1570 - Variabilidade acumulada: 74.14%
# Vetores singulares (eigenfaces): 1580 - Variabilidade acumulada: 74.31%
# Vetores singulares (eigenfaces): 1590 - Variabilidade acumulada: 74.47%
# Vetores singulares (eigenfaces): 1600 - Variabilidade acumulada: 74.64%
# Vetores singulares (eigenfaces): 1610 - Variabilidade acumulada: 74.80%
# Vetores singulares (eigenfaces): 1620 - Variabilidade acumulada: 74.97%
# Vetores singulares (eigenfaces): 1630 - Variabilidade acumulada: 75.13%
# Vetores singulares (eigenfaces): 1640 - Variabilidade acumulada: 75.29%
# Vetores singulares (eigenfaces): 1650 - Variabilidade acumulada: 75.45%
# Vetores singulares (eigenfaces): 1660 - Variabilidade acumulada: 75.61%
# Vetores singulares (eigenfaces): 1670 - Variabilidade acumulada: 75.77%
# Vetores singulares (eigenfaces): 1680 - Variabilidade acumulada: 75.93%
# Vetores singulares (eigenfaces): 1690 - Variabilidade acumulada: 76.09%
# Vetores singulares (eigenfaces): 1700 - Variabilidade acumulada: 76.25%
# Vetores singulares (eigenfaces): 1710 - Variabilidade acumulada: 76.40%
# Vetores singulares (eigenfaces): 1720 - Variabilidade acumulada: 76.56%
# Vetores singulares (eigenfaces): 1730 - Variabilidade acumulada: 76.72%
# Vetores singulares (eigenfaces): 1740 - Variabilidade acumulada: 76.87%
# Vetores singulares (eigenfaces): 1750 - Variabilidade acumulada: 77.02%
# Vetores singulares (eigenfaces): 1760 - Variabilidade acumulada: 77.18%
# Vetores singulares (eigenfaces): 1770 - Variabilidade acumulada: 77.33%
# Vetores singulares (eigenfaces): 1780 - Variabilidade acumulada: 77.48%
# Vetores singulares (eigenfaces): 1790 - Variabilidade acumulada: 77.64%
# Vetores singulares (eigenfaces): 1800 - Variabilidade acumulada: 77.79%
# Vetores singulares (eigenfaces): 1810 - Variabilidade acumulada: 77.94%
# Vetores singulares (eigenfaces): 1820 - Variabilidade acumulada: 78.09%
# Vetores singulares (eigenfaces): 1830 - Variabilidade acumulada: 78.24%
# Vetores singulares (eigenfaces): 1840 - Variabilidade acumulada: 78.38%
# Vetores singulares (eigenfaces): 1850 - Variabilidade acumulada: 78.53%
# Vetores singulares (eigenfaces): 1860 - Variabilidade acumulada: 78.68%
# Vetores singulares (eigenfaces): 1870 - Variabilidade acumulada: 78.83%
# Vetores singulares (eigenfaces): 1880 - Variabilidade acumulada: 78.97%
# Vetores singulares (eigenfaces): 1890 - Variabilidade acumulada: 79.12%
# Vetores singulares (eigenfaces): 1900 - Variabilidade acumulada: 79.26%
# Vetores singulares (eigenfaces): 1910 - Variabilidade acumulada: 79.41%
# Vetores singulares (eigenfaces): 1920 - Variabilidade acumulada: 79.55%
# Vetores singulares (eigenfaces): 1930 - Variabilidade acumulada: 79.69%
# Vetores singulares (eigenfaces): 1940 - Variabilidade acumulada: 79.84%
# Vetores singulares (eigenfaces): 1950 - Variabilidade acumulada: 79.98%
# Vetores singulares (eigenfaces): 1960 - Variabilidade acumulada: 80.12%
# Vetores singulares (eigenfaces): 1970 - Variabilidade acumulada: 80.26%
# Vetores singulares (eigenfaces): 1980 - Variabilidade acumulada: 80.40%
# Vetores singulares (eigenfaces): 1990 - Variabilidade acumulada: 80.54%
# Vetores singulares (eigenfaces): 2000 - Variabilidade acumulada: 80.68%
# Vetores singulares (eigenfaces): 2010 - Variabilidade acumulada: 80.81%
# Vetores singulares (eigenfaces): 2020 - Variabilidade acumulada: 80.95%
# Vetores singulares (eigenfaces): 2030 - Variabilidade acumulada: 81.09%
# Vetores singulares (eigenfaces): 2040 - Variabilidade acumulada: 81.22%
# Vetores singulares (eigenfaces): 2050 - Variabilidade acumulada: 81.36%
# Vetores singulares (eigenfaces): 2060 - Variabilidade acumulada: 81.49%
# Vetores singulares (eigenfaces): 2070 - Variabilidade acumulada: 81.63%
# Vetores singulares (eigenfaces): 2080 - Variabilidade acumulada: 81.76%
# Vetores singulares (eigenfaces): 2090 - Variabilidade acumulada: 81.90%
# Vetores singulares (eigenfaces): 2100 - Variabilidade acumulada: 82.03%
# Vetores singulares (eigenfaces): 2110 - Variabilidade acumulada: 82.16%
# Vetores singulares (eigenfaces): 2120 - Variabilidade acumulada: 82.29%
# Vetores singulares (eigenfaces): 2130 - Variabilidade acumulada: 82.42%
# Vetores singulares (eigenfaces): 2140 - Variabilidade acumulada: 82.55%
# Vetores singulares (eigenfaces): 2150 - Variabilidade acumulada: 82.68%
# Vetores singulares (eigenfaces): 2160 - Variabilidade acumulada: 82.81%
# Vetores singulares (eigenfaces): 2170 - Variabilidade acumulada: 82.94%
# Vetores singulares (eigenfaces): 2180 - Variabilidade acumulada: 83.07%
# Vetores singulares (eigenfaces): 2190 - Variabilidade acumulada: 83.19%
# Vetores singulares (eigenfaces): 2200 - Variabilidade acumulada: 83.32%
# Vetores singulares (eigenfaces): 2210 - Variabilidade acumulada: 83.44%
# Vetores singulares (eigenfaces): 2220 - Variabilidade acumulada: 83.57%
# Vetores singulares (eigenfaces): 2230 - Variabilidade acumulada: 83.69%
# Vetores singulares (eigenfaces): 2240 - Variabilidade acumulada: 83.82%
# Vetores singulares (eigenfaces): 2250 - Variabilidade acumulada: 83.94%
# Vetores singulares (eigenfaces): 2260 - Variabilidade acumulada: 84.06%
# Vetores singulares (eigenfaces): 2270 - Variabilidade acumulada: 84.19%
# Vetores singulares (eigenfaces): 2280 - Variabilidade acumulada: 84.31%
# Vetores singulares (eigenfaces): 2290 - Variabilidade acumulada: 84.43%
# Vetores singulares (eigenfaces): 2300 - Variabilidade acumulada: 84.55%
# Vetores singulares (eigenfaces): 2310 - Variabilidade acumulada: 84.67%
# Vetores singulares (eigenfaces): 2320 - Variabilidade acumulada: 84.79%
# Vetores singulares (eigenfaces): 2330 - Variabilidade acumulada: 84.90%
# Vetores singulares (eigenfaces): 2340 - Variabilidade acumulada: 85.02%
# Vetores singulares (eigenfaces): 2350 - Variabilidade acumulada: 85.14%
# Vetores singulares (eigenfaces): 2360 - Variabilidade acumulada: 85.26%
# Vetores singulares (eigenfaces): 2370 - Variabilidade acumulada: 85.37%
# Vetores singulares (eigenfaces): 2380 - Variabilidade acumulada: 85.49%
# Vetores singulares (eigenfaces): 2390 - Variabilidade acumulada: 85.60%
# Vetores singulares (eigenfaces): 2400 - Variabilidade acumulada: 85.72%
# Vetores singulares (eigenfaces): 2410 - Variabilidade acumulada: 85.83%
# Vetores singulares (eigenfaces): 2420 - Variabilidade acumulada: 85.94%
# Vetores singulares (eigenfaces): 2430 - Variabilidade acumulada: 86.05%
# Vetores singulares (eigenfaces): 2440 - Variabilidade acumulada: 86.17%
# Vetores singulares (eigenfaces): 2450 - Variabilidade acumulada: 86.28%
# Vetores singulares (eigenfaces): 2460 - Variabilidade acumulada: 86.39%
# Vetores singulares (eigenfaces): 2470 - Variabilidade acumulada: 86.50%
# Vetores singulares (eigenfaces): 2480 - Variabilidade acumulada: 86.61%
# Vetores singulares (eigenfaces): 2490 - Variabilidade acumulada: 86.72%
# Vetores singulares (eigenfaces): 2500 - Variabilidade acumulada: 86.82%
# Vetores singulares (eigenfaces): 2510 - Variabilidade acumulada: 86.93%
# Vetores singulares (eigenfaces): 2520 - Variabilidade acumulada: 87.04%
# Vetores singulares (eigenfaces): 2530 - Variabilidade acumulada: 87.14%
# Vetores singulares (eigenfaces): 2540 - Variabilidade acumulada: 87.25%
# Vetores singulares (eigenfaces): 2550 - Variabilidade acumulada: 87.35%
# Vetores singulares (eigenfaces): 2560 - Variabilidade acumulada: 87.46%
# Vetores singulares (eigenfaces): 2570 - Variabilidade acumulada: 87.56%
# Vetores singulares (eigenfaces): 2580 - Variabilidade acumulada: 87.67%
# Vetores singulares (eigenfaces): 2590 - Variabilidade acumulada: 87.77%
# Vetores singulares (eigenfaces): 2600 - Variabilidade acumulada: 87.87%
# Vetores singulares (eigenfaces): 2610 - Variabilidade acumulada: 87.97%
# Vetores singulares (eigenfaces): 2620 - Variabilidade acumulada: 88.07%
# Vetores singulares (eigenfaces): 2630 - Variabilidade acumulada: 88.17%
# Vetores singulares (eigenfaces): 2640 - Variabilidade acumulada: 88.27%
# Vetores singulares (eigenfaces): 2650 - Variabilidade acumulada: 88.37%
# Vetores singulares (eigenfaces): 2660 - Variabilidade acumulada: 88.47%
# Vetores singulares (eigenfaces): 2670 - Variabilidade acumulada: 88.57%
# Vetores singulares (eigenfaces): 2680 - Variabilidade acumulada: 88.67%
# Vetores singulares (eigenfaces): 2690 - Variabilidade acumulada: 88.77%
# Vetores singulares (eigenfaces): 2700 - Variabilidade acumulada: 88.86%
# Vetores singulares (eigenfaces): 2710 - Variabilidade acumulada: 88.96%
# Vetores singulares (eigenfaces): 2720 - Variabilidade acumulada: 89.05%
# Vetores singulares (eigenfaces): 2730 - Variabilidade acumulada: 89.15%
# Vetores singulares (eigenfaces): 2740 - Variabilidade acumulada: 89.24%
# Vetores singulares (eigenfaces): 2750 - Variabilidade acumulada: 89.34%
# Vetores singulares (eigenfaces): 2760 - Variabilidade acumulada: 89.43%
# Vetores singulares (eigenfaces): 2770 - Variabilidade acumulada: 89.52%
# Vetores singulares (eigenfaces): 2780 - Variabilidade acumulada: 89.62%
# Vetores singulares (eigenfaces): 2790 - Variabilidade acumulada: 89.71%
# Vetores singulares (eigenfaces): 2800 - Variabilidade acumulada: 89.80%
# Vetores singulares (eigenfaces): 2810 - Variabilidade acumulada: 89.89%
# Vetores singulares (eigenfaces): 2820 - Variabilidade acumulada: 89.98%
# Vetores singulares (eigenfaces): 2830 - Variabilidade acumulada: 90.07%
# Vetores singulares (eigenfaces): 2840 - Variabilidade acumulada: 90.16%
# Vetores singulares (eigenfaces): 2850 - Variabilidade acumulada: 90.25%
# Vetores singulares (eigenfaces): 2860 - Variabilidade acumulada: 90.34%
# Vetores singulares (eigenfaces): 2870 - Variabilidade acumulada: 90.42%
# Vetores singulares (eigenfaces): 2880 - Variabilidade acumulada: 90.51%
# Vetores singulares (eigenfaces): 2890 - Variabilidade acumulada: 90.60%
# Vetores singulares (eigenfaces): 2900 - Variabilidade acumulada: 90.69%
# Vetores singulares (eigenfaces): 2910 - Variabilidade acumulada: 90.77%
# Vetores singulares (eigenfaces): 2920 - Variabilidade acumulada: 90.86%
# Vetores singulares (eigenfaces): 2930 - Variabilidade acumulada: 90.94%
# Vetores singulares (eigenfaces): 2940 - Variabilidade acumulada: 91.02%
# Vetores singulares (eigenfaces): 2950 - Variabilidade acumulada: 91.11%
# Vetores singulares (eigenfaces): 2960 - Variabilidade acumulada: 91.19%
# Vetores singulares (eigenfaces): 2970 - Variabilidade acumulada: 91.27%
# Vetores singulares (eigenfaces): 2980 - Variabilidade acumulada: 91.36%
# Vetores singulares (eigenfaces): 2990 - Variabilidade acumulada: 91.44%
# Vetores singulares (eigenfaces): 3000 - Variabilidade acumulada: 91.52%
# Vetores singulares (eigenfaces): 3010 - Variabilidade acumulada: 91.60%
# Vetores singulares (eigenfaces): 3020 - Variabilidade acumulada: 91.68%
# Vetores singulares (eigenfaces): 3030 - Variabilidade acumulada: 91.76%
# Vetores singulares (eigenfaces): 3040 - Variabilidade acumulada: 91.84%
# Vetores singulares (eigenfaces): 3050 - Variabilidade acumulada: 91.92%
# Vetores singulares (eigenfaces): 3060 - Variabilidade acumulada: 92.00%
# Vetores singulares (eigenfaces): 3070 - Variabilidade acumulada: 92.08%
# Vetores singulares (eigenfaces): 3080 - Variabilidade acumulada: 92.15%
# Vetores singulares (eigenfaces): 3090 - Variabilidade acumulada: 92.23%
# Vetores singulares (eigenfaces): 3100 - Variabilidade acumulada: 92.31%
# Vetores singulares (eigenfaces): 3110 - Variabilidade acumulada: 92.38%
# Vetores singulares (eigenfaces): 3120 - Variabilidade acumulada: 92.46%
# Vetores singulares (eigenfaces): 3130 - Variabilidade acumulada: 92.53%
# Vetores singulares (eigenfaces): 3140 - Variabilidade acumulada: 92.61%
# Vetores singulares (eigenfaces): 3150 - Variabilidade acumulada: 92.68%
# Vetores singulares (eigenfaces): 3160 - Variabilidade acumulada: 92.76%
# Vetores singulares (eigenfaces): 3170 - Variabilidade acumulada: 92.83%
# Vetores singulares (eigenfaces): 3180 - Variabilidade acumulada: 92.90%
# Vetores singulares (eigenfaces): 3190 - Variabilidade acumulada: 92.97%
# Vetores singulares (eigenfaces): 3200 - Variabilidade acumulada: 93.05%
# Vetores singulares (eigenfaces): 3210 - Variabilidade acumulada: 93.12%
# Vetores singulares (eigenfaces): 3220 - Variabilidade acumulada: 93.19%
# Vetores singulares (eigenfaces): 3230 - Variabilidade acumulada: 93.26%
# Vetores singulares (eigenfaces): 3240 - Variabilidade acumulada: 93.33%
# Vetores singulares (eigenfaces): 3250 - Variabilidade acumulada: 93.40%
# Vetores singulares (eigenfaces): 3260 - Variabilidade acumulada: 93.47%
# Vetores singulares (eigenfaces): 3270 - Variabilidade acumulada: 93.54%
# Vetores singulares (eigenfaces): 3280 - Variabilidade acumulada: 93.61%
# Vetores singulares (eigenfaces): 3290 - Variabilidade acumulada: 93.67%
# Vetores singulares (eigenfaces): 3300 - Variabilidade acumulada: 93.74%
# Vetores singulares (eigenfaces): 3310 - Variabilidade acumulada: 93.81%
# Vetores singulares (eigenfaces): 3320 - Variabilidade acumulada: 93.88%
# Vetores singulares (eigenfaces): 3330 - Variabilidade acumulada: 93.94%
# Vetores singulares (eigenfaces): 3340 - Variabilidade acumulada: 94.01%
# Vetores singulares (eigenfaces): 3350 - Variabilidade acumulada: 94.07%
# Vetores singulares (eigenfaces): 3360 - Variabilidade acumulada: 94.14%
# Vetores singulares (eigenfaces): 3370 - Variabilidade acumulada: 94.20%
# Vetores singulares (eigenfaces): 3380 - Variabilidade acumulada: 94.27%
# Vetores singulares (eigenfaces): 3390 - Variabilidade acumulada: 94.33%
# Vetores singulares (eigenfaces): 3400 - Variabilidade acumulada: 94.39%
# Vetores singulares (eigenfaces): 3410 - Variabilidade acumulada: 94.46%
# Vetores singulares (eigenfaces): 3420 - Variabilidade acumulada: 94.52%
# Vetores singulares (eigenfaces): 3430 - Variabilidade acumulada: 94.58%
# Vetores singulares (eigenfaces): 3440 - Variabilidade acumulada: 94.64%
# Vetores singulares (eigenfaces): 3450 - Variabilidade acumulada: 94.70%
# Vetores singulares (eigenfaces): 3460 - Variabilidade acumulada: 94.77%
# Vetores singulares (eigenfaces): 3470 - Variabilidade acumulada: 94.83%
# Vetores singulares (eigenfaces): 3480 - Variabilidade acumulada: 94.89%
# Vetores singulares (eigenfaces): 3490 - Variabilidade acumulada: 94.95%
# Vetores singulares (eigenfaces): 3500 - Variabilidade acumulada: 95.00%
# Vetores singulares (eigenfaces): 3510 - Variabilidade acumulada: 95.06%
# Vetores singulares (eigenfaces): 3520 - Variabilidade acumulada: 95.12%
# Vetores singulares (eigenfaces): 3530 - Variabilidade acumulada: 95.18%
# Vetores singulares (eigenfaces): 3540 - Variabilidade acumulada: 95.24%
# Vetores singulares (eigenfaces): 3550 - Variabilidade acumulada: 95.29%
# Vetores singulares (eigenfaces): 3560 - Variabilidade acumulada: 95.35%
# Vetores singulares (eigenfaces): 3570 - Variabilidade acumulada: 95.41%
# Vetores singulares (eigenfaces): 3580 - Variabilidade acumulada: 95.46%
# Vetores singulares (eigenfaces): 3590 - Variabilidade acumulada: 95.52%
# Vetores singulares (eigenfaces): 3600 - Variabilidade acumulada: 95.57%
# Vetores singulares (eigenfaces): 3610 - Variabilidade acumulada: 95.63%
# Vetores singulares (eigenfaces): 3620 - Variabilidade acumulada: 95.68%
# Vetores singulares (eigenfaces): 3630 - Variabilidade acumulada: 95.74%
# Vetores singulares (eigenfaces): 3640 - Variabilidade acumulada: 95.79%
# Vetores singulares (eigenfaces): 3650 - Variabilidade acumulada: 95.85%
# Vetores singulares (eigenfaces): 3660 - Variabilidade acumulada: 95.90%
# Vetores singulares (eigenfaces): 3670 - Variabilidade acumulada: 95.95%
# Vetores singulares (eigenfaces): 3680 - Variabilidade acumulada: 96.00%
# Vetores singulares (eigenfaces): 3690 - Variabilidade acumulada: 96.05%
# Vetores singulares (eigenfaces): 3700 - Variabilidade acumulada: 96.11%
# Vetores singulares (eigenfaces): 3710 - Variabilidade acumulada: 96.16%
# Vetores singulares (eigenfaces): 3720 - Variabilidade acumulada: 96.21%
# Vetores singulares (eigenfaces): 3730 - Variabilidade acumulada: 96.26%
# Vetores singulares (eigenfaces): 3740 - Variabilidade acumulada: 96.31%
# Vetores singulares (eigenfaces): 3750 - Variabilidade acumulada: 96.36%
# Vetores singulares (eigenfaces): 3760 - Variabilidade acumulada: 96.41%
# Vetores singulares (eigenfaces): 3770 - Variabilidade acumulada: 96.45%
# Vetores singulares (eigenfaces): 3780 - Variabilidade acumulada: 96.50%
# Vetores singulares (eigenfaces): 3790 - Variabilidade acumulada: 96.55%
# Vetores singulares (eigenfaces): 3800 - Variabilidade acumulada: 96.60%
# Vetores singulares (eigenfaces): 3810 - Variabilidade acumulada: 96.65%
# Vetores singulares (eigenfaces): 3820 - Variabilidade acumulada: 96.69%
# Vetores singulares (eigenfaces): 3830 - Variabilidade acumulada: 96.74%
# Vetores singulares (eigenfaces): 3840 - Variabilidade acumulada: 96.79%
# Vetores singulares (eigenfaces): 3850 - Variabilidade acumulada: 96.83%
# Vetores singulares (eigenfaces): 3860 - Variabilidade acumulada: 96.88%
# Vetores singulares (eigenfaces): 3870 - Variabilidade acumulada: 96.92%
# Vetores singulares (eigenfaces): 3880 - Variabilidade acumulada: 96.97%
# Vetores singulares (eigenfaces): 3890 - Variabilidade acumulada: 97.01%
# Vetores singulares (eigenfaces): 3900 - Variabilidade acumulada: 97.06%
# Vetores singulares (eigenfaces): 3910 - Variabilidade acumulada: 97.10%
# Vetores singulares (eigenfaces): 3920 - Variabilidade acumulada: 97.14%
# Vetores singulares (eigenfaces): 3930 - Variabilidade acumulada: 97.19%
# Vetores singulares (eigenfaces): 3940 - Variabilidade acumulada: 97.23%
# Vetores singulares (eigenfaces): 3950 - Variabilidade acumulada: 97.27%
# Vetores singulares (eigenfaces): 3960 - Variabilidade acumulada: 97.31%
# Vetores singulares (eigenfaces): 3970 - Variabilidade acumulada: 97.35%
# Vetores singulares (eigenfaces): 3980 - Variabilidade acumulada: 97.39%
# Vetores singulares (eigenfaces): 3990 - Variabilidade acumulada: 97.44%
# Vetores singulares (eigenfaces): 4000 - Variabilidade acumulada: 97.48%
# Vetores singulares (eigenfaces): 4010 - Variabilidade acumulada: 97.52%
# Vetores singulares (eigenfaces): 4020 - Variabilidade acumulada: 97.56%
# Vetores singulares (eigenfaces): 4030 - Variabilidade acumulada: 97.59%
# Vetores singulares (eigenfaces): 4040 - Variabilidade acumulada: 97.63%
# Vetores singulares (eigenfaces): 4050 - Variabilidade acumulada: 97.67%
# Vetores singulares (eigenfaces): 4060 - Variabilidade acumulada: 97.71%
# Vetores singulares (eigenfaces): 4070 - Variabilidade acumulada: 97.75%
# Vetores singulares (eigenfaces): 4080 - Variabilidade acumulada: 97.79%
# Vetores singulares (eigenfaces): 4090 - Variabilidade acumulada: 97.82%
# Vetores singulares (eigenfaces): 4100 - Variabilidade acumulada: 97.86%
# Vetores singulares (eigenfaces): 4110 - Variabilidade acumulada: 97.90%
# Vetores singulares (eigenfaces): 4120 - Variabilidade acumulada: 97.93%
# Vetores singulares (eigenfaces): 4130 - Variabilidade acumulada: 97.97%
# Vetores singulares (eigenfaces): 4140 - Variabilidade acumulada: 98.01%
# Vetores singulares (eigenfaces): 4150 - Variabilidade acumulada: 98.04%
# Vetores singulares (eigenfaces): 4160 - Variabilidade acumulada: 98.08%
# Vetores singulares (eigenfaces): 4170 - Variabilidade acumulada: 98.11%
# Vetores singulares (eigenfaces): 4180 - Variabilidade acumulada: 98.15%
# Vetores singulares (eigenfaces): 4190 - Variabilidade acumulada: 98.18%
# Vetores singulares (eigenfaces): 4200 - Variabilidade acumulada: 98.21%
# Vetores singulares (eigenfaces): 4210 - Variabilidade acumulada: 98.25%
# Vetores singulares (eigenfaces): 4220 - Variabilidade acumulada: 98.28%
# Vetores singulares (eigenfaces): 4230 - Variabilidade acumulada: 98.31%
# Vetores singulares (eigenfaces): 4240 - Variabilidade acumulada: 98.34%
# Vetores singulares (eigenfaces): 4250 - Variabilidade acumulada: 98.38%
# Vetores singulares (eigenfaces): 4260 - Variabilidade acumulada: 98.41%
# Vetores singulares (eigenfaces): 4270 - Variabilidade acumulada: 98.44%
# Vetores singulares (eigenfaces): 4280 - Variabilidade acumulada: 98.47%
# Vetores singulares (eigenfaces): 4290 - Variabilidade acumulada: 98.50%
# Vetores singulares (eigenfaces): 4300 - Variabilidade acumulada: 98.53%
# Vetores singulares (eigenfaces): 4310 - Variabilidade acumulada: 98.56%
# Vetores singulares (eigenfaces): 4320 - Variabilidade acumulada: 98.59%
# Vetores singulares (eigenfaces): 4330 - Variabilidade acumulada: 98.62%
# Vetores singulares (eigenfaces): 4340 - Variabilidade acumulada: 98.65%
# Vetores singulares (eigenfaces): 4350 - Variabilidade acumulada: 98.68%
# Vetores singulares (eigenfaces): 4360 - Variabilidade acumulada: 98.71%
# Vetores singulares (eigenfaces): 4370 - Variabilidade acumulada: 98.74%
# Vetores singulares (eigenfaces): 4380 - Variabilidade acumulada: 98.76%
# Vetores singulares (eigenfaces): 4390 - Variabilidade acumulada: 98.79%
# Vetores singulares (eigenfaces): 4400 - Variabilidade acumulada: 98.82%
# Vetores singulares (eigenfaces): 4410 - Variabilidade acumulada: 98.84%
# Vetores singulares (eigenfaces): 4420 - Variabilidade acumulada: 98.87%
# Vetores singulares (eigenfaces): 4430 - Variabilidade acumulada: 98.90%
# Vetores singulares (eigenfaces): 4440 - Variabilidade acumulada: 98.92%
# Vetores singulares (eigenfaces): 4450 - Variabilidade acumulada: 98.95%
# Vetores singulares (eigenfaces): 4460 - Variabilidade acumulada: 98.97%
# Vetores singulares (eigenfaces): 4470 - Variabilidade acumulada: 99.00%
# Vetores singulares (eigenfaces): 4480 - Variabilidade acumulada: 99.02%
# Vetores singulares (eigenfaces): 4490 - Variabilidade acumulada: 99.05%
# Vetores singulares (eigenfaces): 4500 - Variabilidade acumulada: 99.07%
# Vetores singulares (eigenfaces): 4510 - Variabilidade acumulada: 99.10%
# Vetores singulares (eigenfaces): 4520 - Variabilidade acumulada: 99.12%
# Vetores singulares (eigenfaces): 4530 - Variabilidade acumulada: 99.14%
# Vetores singulares (eigenfaces): 4540 - Variabilidade acumulada: 99.16%
# Vetores singulares (eigenfaces): 4550 - Variabilidade acumulada: 99.19%
# Vetores singulares (eigenfaces): 4560 - Variabilidade acumulada: 99.21%
# Vetores singulares (eigenfaces): 4570 - Variabilidade acumulada: 99.23%
# Vetores singulares (eigenfaces): 4580 - Variabilidade acumulada: 99.25%
# Vetores singulares (eigenfaces): 4590 - Variabilidade acumulada: 99.27%
# Vetores singulares (eigenfaces): 4600 - Variabilidade acumulada: 99.29%
# Vetores singulares (eigenfaces): 4610 - Variabilidade acumulada: 99.32%
# Vetores singulares (eigenfaces): 4620 - Variabilidade acumulada: 99.34%
# Vetores singulares (eigenfaces): 4630 - Variabilidade acumulada: 99.36%
# Vetores singulares (eigenfaces): 4640 - Variabilidade acumulada: 99.37%
# Vetores singulares (eigenfaces): 4650 - Variabilidade acumulada: 99.39%
# Vetores singulares (eigenfaces): 4660 - Variabilidade acumulada: 99.41%
# Vetores singulares (eigenfaces): 4670 - Variabilidade acumulada: 99.43%
# Vetores singulares (eigenfaces): 4680 - Variabilidade acumulada: 99.45%
# Vetores singulares (eigenfaces): 4690 - Variabilidade acumulada: 99.47%
# Vetores singulares (eigenfaces): 4700 - Variabilidade acumulada: 99.49%
# Vetores singulares (eigenfaces): 4710 - Variabilidade acumulada: 99.50%
# Vetores singulares (eigenfaces): 4720 - Variabilidade acumulada: 99.52%
# Vetores singulares (eigenfaces): 4730 - Variabilidade acumulada: 99.54%
# Vetores singulares (eigenfaces): 4740 - Variabilidade acumulada: 99.55%
# Vetores singulares (eigenfaces): 4750 - Variabilidade acumulada: 99.57%
# Vetores singulares (eigenfaces): 4760 - Variabilidade acumulada: 99.59%
# Vetores singulares (eigenfaces): 4770 - Variabilidade acumulada: 99.60%
# Vetores singulares (eigenfaces): 4780 - Variabilidade acumulada: 99.62%
# Vetores singulares (eigenfaces): 4790 - Variabilidade acumulada: 99.63%
# Vetores singulares (eigenfaces): 4800 - Variabilidade acumulada: 99.65%
# Vetores singulares (eigenfaces): 4810 - Variabilidade acumulada: 99.66%
# Vetores singulares (eigenfaces): 4820 - Variabilidade acumulada: 99.68%
# Vetores singulares (eigenfaces): 4830 - Variabilidade acumulada: 99.69%
# Vetores singulares (eigenfaces): 4840 - Variabilidade acumulada: 99.70%
# Vetores singulares (eigenfaces): 4850 - Variabilidade acumulada: 99.72%
# Vetores singulares (eigenfaces): 4860 - Variabilidade acumulada: 99.73%
# Vetores singulares (eigenfaces): 4870 - Variabilidade acumulada: 99.74%
# Vetores singulares (eigenfaces): 4880 - Variabilidade acumulada: 99.75%
# Vetores singulares (eigenfaces): 4890 - Variabilidade acumulada: 99.76%
# Vetores singulares (eigenfaces): 4900 - Variabilidade acumulada: 99.78%
# Vetores singulares (eigenfaces): 4910 - Variabilidade acumulada: 99.79%
# Vetores singulares (eigenfaces): 4920 - Variabilidade acumulada: 99.80%
# Vetores singulares (eigenfaces): 4930 - Variabilidade acumulada: 99.81%
# Vetores singulares (eigenfaces): 4940 - Variabilidade acumulada: 99.82%
# Vetores singulares (eigenfaces): 4950 - Variabilidade acumulada: 99.83%
# Vetores singulares (eigenfaces): 4960 - Variabilidade acumulada: 99.84%
# Vetores singulares (eigenfaces): 4970 - Variabilidade acumulada: 99.85%
# Vetores singulares (eigenfaces): 4980 - Variabilidade acumulada: 99.86%
# Vetores singulares (eigenfaces): 4990 - Variabilidade acumulada: 99.87%
# Vetores singulares (eigenfaces): 5000 - Variabilidade acumulada: 99.88%
# Vetores singulares (eigenfaces): 5010 - Variabilidade acumulada: 99.88%
# Vetores singulares (eigenfaces): 5020 - Variabilidade acumulada: 99.89%
# Vetores singulares (eigenfaces): 5030 - Variabilidade acumulada: 99.90%
# Vetores singulares (eigenfaces): 5040 - Variabilidade acumulada: 99.91%
# Vetores singulares (eigenfaces): 5050 - Variabilidade acumulada: 99.91%
# Vetores singulares (eigenfaces): 5060 - Variabilidade acumulada: 99.92%
# Vetores singulares (eigenfaces): 5070 - Variabilidade acumulada: 99.93%
# Vetores singulares (eigenfaces): 5080 - Variabilidade acumulada: 99.93%
# Vetores singulares (eigenfaces): 5090 - Variabilidade acumulada: 99.94%
# Vetores singulares (eigenfaces): 5100 - Variabilidade acumulada: 99.94%
# Vetores singulares (eigenfaces): 5110 - Variabilidade acumulada: 99.95%
# Vetores singulares (eigenfaces): 5120 - Variabilidade acumulada: 99.95%
# Vetores singulares (eigenfaces): 5130 - Variabilidade acumulada: 99.96%
# Vetores singulares (eigenfaces): 5140 - Variabilidade acumulada: 99.96%
# Vetores singulares (eigenfaces): 5150 - Variabilidade acumulada: 99.97%
# Vetores singulares (eigenfaces): 5160 - Variabilidade acumulada: 99.97%
# Vetores singulares (eigenfaces): 5170 - Variabilidade acumulada: 99.97%
# Vetores singulares (eigenfaces): 5180 - Variabilidade acumulada: 99.98%
# Vetores singulares (eigenfaces): 5190 - Variabilidade acumulada: 99.98%
# Vetores singulares (eigenfaces): 5200 - Variabilidade acumulada: 99.98%
# Vetores singulares (eigenfaces): 5210 - Variabilidade acumulada: 99.99%
# Vetores singulares (eigenfaces): 5220 - Variabilidade acumulada: 99.99%
# Vetores singulares (eigenfaces): 5230 - Variabilidade acumulada: 99.99%
# Vetores singulares (eigenfaces): 5240 - Variabilidade acumulada: 99.99%
# Vetores singulares (eigenfaces): 5250 - Variabilidade acumulada: 99.99%
# Vetores singulares (eigenfaces): 5260 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5270 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5280 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5290 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5300 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5310 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5320 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5330 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5340 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5350 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5360 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5370 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5380 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5390 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5400 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5410 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5420 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5430 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5440 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5450 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5460 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5470 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5480 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5490 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5500 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5510 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5520 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5530 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5540 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5550 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5560 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5570 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5580 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5590 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5600 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5610 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5620 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5630 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5640 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5650 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5660 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5670 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5680 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5690 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5700 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5710 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5720 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5730 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5740 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5750 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5760 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5770 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5780 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5790 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5800 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5810 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5820 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5830 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5840 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5850 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5860 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5870 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5880 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5890 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5900 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5910 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5920 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5930 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5940 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5950 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5960 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5970 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5980 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 5990 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6000 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6010 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6020 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6030 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6040 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6050 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6060 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6070 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6080 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6090 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6100 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6110 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6120 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6130 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6140 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6150 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6160 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6170 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6180 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6190 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6200 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6210 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6220 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6230 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6240 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6250 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6260 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6270 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6280 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6290 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6300 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6310 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6320 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6330 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6340 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6350 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6360 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6370 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6380 - Variabilidade acumulada: 100.00%
# Vetores singulares (eigenfaces): 6390 - Variabilidade acumulada: 100.00%

# %%
plt.figure(figsize=(8,5))
plt.plot(eigen,acc,linewidth=2.0)
plt.grid()
plt.ylabel("Variabilidade acumulada (%)")
plt.xlabel("Eigenblocks")
plt.axis([0,len(s),0,101])
plt.show()

# %%
r = 92
# r = get_r_number_from_accumulated_variability(22.2, s)

U_r = get_first_n_components(u, r)

x_train_projected = U_r.T @ x_train_centralized
print("x_train_projected.shape:", x_train_projected.shape)

x_test_projected = U_r.T @ x_test_centralized
print("x_test_projected.shape:", x_test_projected.shape)
# Out:
# x_train_projected.shape: (92, 28000)
# x_test_projected.shape: (92, 12000)

# %%
acertos = 0
erros = 0

# for i in range(GlobalSettings.N_TESTS_USED):
for i in range(len(x_test_paths)):
    test_img_proj = x_test_projected[:, i]
    
    distances = np.linalg.norm(x_train_projected.T - test_img_proj, axis=1)
    
    # Find the nearest training sample
    nearest_index = np.argmin(distances)
    
    # Compare the class label of the nearest training sample to the test sample's label
    if y_test[i] == y_train[nearest_index]:
        acertos += 1
    else:
        erros += 1
       
total = acertos+erros

print("Quantidade de acertos:", acertos)
print("Quantidade de erros:", erros)
print("Total:", total)
print("Acurácia: {:.2f}%".format(100*(acertos/total)))
# Out:
# Quantidade de acertos: 7482
# Quantidade de erros: 4518
# Total: 12000
# Acurácia: 62.35%

# %%
ACERTOS = []
ERROS = []
TAXA_ACERTOS = []
VARIABILIDADE_ACUMULADA = []
EIGENBLOCKS = []

for r in range(get_r_number_from_accumulated_variability(18, s), get_r_number_from_accumulated_variability(26, s), 1):
    U_r = get_first_n_components(u, r)

    x_train_projected = U_r.T @ x_train_centralized
    print("x_train_projected.shape:", x_train_projected.shape)
    
    x_test_projected = U_r.T @ x_test_centralized
    print("x_test_projected.shape:", x_test_projected.shape)
    
    acertos = 0
    erros = 0
    
    for i in range(GlobalSettings.N_TESTS_USED):
        test_img_proj = x_test_projected[:, i]
        
        distances = np.linalg.norm(x_train_projected.T - test_img_proj, axis=1)
        
        # Find the nearest training sample
        nearest_index = np.argmin(distances)
        
        # Compare the class label of the nearest training sample to the test sample's label
        if y_test[i] == y_train[nearest_index]:
            acertos += 1
        else:
            erros += 1
            
    total = acertos+erros

    ACERTOS.append(acertos)
    ERROS.append(erros)
    TAXA_ACERTOS.append(100*(acertos/total))
    VARIABILIDADE_ACUMULADA.append(calculate_accumulated_variability(s,r))
    EIGENBLOCKS.append(r)

    print("Quantidade de eigenblocks:", r)
    print("Quantidade de acertos:", acertos)
    print("Quantidade de erros:", erros)
    print("Total:", total)
    print("Acurácia: {:.2f}%".format(100*(acertos/total)))
    print("\n")
# Out:
# x_train_projected.shape: (40, 28000)
# x_test_projected.shape: (40, 12000)
# Quantidade de eigenblocks: 40
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (41, 28000)
# x_test_projected.shape: (41, 12000)
# Quantidade de eigenblocks: 41
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (42, 28000)
# x_test_projected.shape: (42, 12000)
# Quantidade de eigenblocks: 42
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (43, 28000)
# x_test_projected.shape: (43, 12000)
# Quantidade de eigenblocks: 43
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%
#
#
# x_train_projected.shape: (44, 28000)
# x_test_projected.shape: (44, 12000)
# Quantidade de eigenblocks: 44
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%
#
#
# x_train_projected.shape: (45, 28000)
# x_test_projected.shape: (45, 12000)
# Quantidade de eigenblocks: 45
# Quantidade de acertos: 121
# Quantidade de erros: 79
# Total: 200
# Acurácia: 60.50%
#
#
# x_train_projected.shape: (46, 28000)
# x_test_projected.shape: (46, 12000)
# Quantidade de eigenblocks: 46
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (47, 28000)
# x_test_projected.shape: (47, 12000)
# Quantidade de eigenblocks: 47
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (48, 28000)
# x_test_projected.shape: (48, 12000)
# Quantidade de eigenblocks: 48
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%
#
#
# x_train_projected.shape: (49, 28000)
# x_test_projected.shape: (49, 12000)
# Quantidade de eigenblocks: 49
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (50, 28000)
# x_test_projected.shape: (50, 12000)
# Quantidade de eigenblocks: 50
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (51, 28000)
# x_test_projected.shape: (51, 12000)
# Quantidade de eigenblocks: 51
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (52, 28000)
# x_test_projected.shape: (52, 12000)
# Quantidade de eigenblocks: 52
# Quantidade de acertos: 126
# Quantidade de erros: 74
# Total: 200
# Acurácia: 63.00%
#
#
# x_train_projected.shape: (53, 28000)
# x_test_projected.shape: (53, 12000)
# Quantidade de eigenblocks: 53
# Quantidade de acertos: 128
# Quantidade de erros: 72
# Total: 200
# Acurácia: 64.00%
#
#
# x_train_projected.shape: (54, 28000)
# x_test_projected.shape: (54, 12000)
# Quantidade de eigenblocks: 54
# Quantidade de acertos: 128
# Quantidade de erros: 72
# Total: 200
# Acurácia: 64.00%
#
#
# x_train_projected.shape: (55, 28000)
# x_test_projected.shape: (55, 12000)
# Quantidade de eigenblocks: 55
# Quantidade de acertos: 127
# Quantidade de erros: 73
# Total: 200
# Acurácia: 63.50%
#
#
# x_train_projected.shape: (56, 28000)
# x_test_projected.shape: (56, 12000)
# Quantidade de eigenblocks: 56
# Quantidade de acertos: 126
# Quantidade de erros: 74
# Total: 200
# Acurácia: 63.00%
#
#
# x_train_projected.shape: (57, 28000)
# x_test_projected.shape: (57, 12000)
# Quantidade de eigenblocks: 57
# Quantidade de acertos: 126
# Quantidade de erros: 74
# Total: 200
# Acurácia: 63.00%
#
#
# x_train_projected.shape: (58, 28000)
# x_test_projected.shape: (58, 12000)
# Quantidade de eigenblocks: 58
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (59, 28000)
# x_test_projected.shape: (59, 12000)
# Quantidade de eigenblocks: 59
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (60, 28000)
# x_test_projected.shape: (60, 12000)
# Quantidade de eigenblocks: 60
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (61, 28000)
# x_test_projected.shape: (61, 12000)
# Quantidade de eigenblocks: 61
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (62, 28000)
# x_test_projected.shape: (62, 12000)
# Quantidade de eigenblocks: 62
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (63, 28000)
# x_test_projected.shape: (63, 12000)
# Quantidade de eigenblocks: 63
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (64, 28000)
# x_test_projected.shape: (64, 12000)
# Quantidade de eigenblocks: 64
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (65, 28000)
# x_test_projected.shape: (65, 12000)
# Quantidade de eigenblocks: 65
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (66, 28000)
# x_test_projected.shape: (66, 12000)
# Quantidade de eigenblocks: 66
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (67, 28000)
# x_test_projected.shape: (67, 12000)
# Quantidade de eigenblocks: 67
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (68, 28000)
# x_test_projected.shape: (68, 12000)
# Quantidade de eigenblocks: 68
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (69, 28000)
# x_test_projected.shape: (69, 12000)
# Quantidade de eigenblocks: 69
# Quantidade de acertos: 122
# Quantidade de erros: 78
# Total: 200
# Acurácia: 61.00%
#
#
# x_train_projected.shape: (70, 28000)
# x_test_projected.shape: (70, 12000)
# Quantidade de eigenblocks: 70
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (71, 28000)
# x_test_projected.shape: (71, 12000)
# Quantidade de eigenblocks: 71
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (72, 28000)
# x_test_projected.shape: (72, 12000)
# Quantidade de eigenblocks: 72
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (73, 28000)
# x_test_projected.shape: (73, 12000)
# Quantidade de eigenblocks: 73
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (74, 28000)
# x_test_projected.shape: (74, 12000)
# Quantidade de eigenblocks: 74
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (75, 28000)
# x_test_projected.shape: (75, 12000)
# Quantidade de eigenblocks: 75
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (76, 28000)
# x_test_projected.shape: (76, 12000)
# Quantidade de eigenblocks: 76
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (77, 28000)
# x_test_projected.shape: (77, 12000)
# Quantidade de eigenblocks: 77
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%
#
#
# x_train_projected.shape: (78, 28000)
# x_test_projected.shape: (78, 12000)
# Quantidade de eigenblocks: 78
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%
#
#
# x_train_projected.shape: (79, 28000)
# x_test_projected.shape: (79, 12000)
# Quantidade de eigenblocks: 79
# Quantidade de acertos: 123
# Quantidade de erros: 77
# Total: 200
# Acurácia: 61.50%
#
#
# x_train_projected.shape: (80, 28000)
# x_test_projected.shape: (80, 12000)
# Quantidade de eigenblocks: 80
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%
#
#
# x_train_projected.shape: (81, 28000)
# x_test_projected.shape: (81, 12000)
# Quantidade de eigenblocks: 81
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (82, 28000)
# x_test_projected.shape: (82, 12000)
# Quantidade de eigenblocks: 82
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (83, 28000)
# x_test_projected.shape: (83, 12000)
# Quantidade de eigenblocks: 83
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (84, 28000)
# x_test_projected.shape: (84, 12000)
# Quantidade de eigenblocks: 84
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (85, 28000)
# x_test_projected.shape: (85, 12000)
# Quantidade de eigenblocks: 85
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (86, 28000)
# x_test_projected.shape: (86, 12000)
# Quantidade de eigenblocks: 86
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (87, 28000)
# x_test_projected.shape: (87, 12000)
# Quantidade de eigenblocks: 87
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (88, 28000)
# x_test_projected.shape: (88, 12000)
# Quantidade de eigenblocks: 88
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (89, 28000)
# x_test_projected.shape: (89, 12000)
# Quantidade de eigenblocks: 89
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (90, 28000)
# x_test_projected.shape: (90, 12000)
# Quantidade de eigenblocks: 90
# Quantidade de acertos: 125
# Quantidade de erros: 75
# Total: 200
# Acurácia: 62.50%
#
#
# x_train_projected.shape: (91, 28000)
# x_test_projected.shape: (91, 12000)
# Quantidade de eigenblocks: 91
# Quantidade de acertos: 124
# Quantidade de erros: 76
# Total: 200
# Acurácia: 62.00%

# %%
acertos = np.array(ACERTOS)
erros = np.array(ERROS)
taxaAcerto = np.array(TAXA_ACERTOS)
variabilidadeAcumulada = np.array(VARIABILIDADE_ACUMULADA)
num_eigenblocks = np.array(EIGENBLOCKS)

plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada,taxaAcerto,lw=3.0)
plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.show()


plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada, taxaAcerto, lw=3.0, marker='o')

# Add annotations for each point
for x, y, n in zip(variabilidadeAcumulada, taxaAcerto, num_eigenblocks):
    plt.annotate(f'{n}', (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.title("Acurácia vs Variabilidade Acumulada with Eigenblocks")
plt.show()

# %%
ACERTOS = []
ERROS = []
TAXA_ACERTOS = []
VARIABILIDADE_ACUMULADA = []
EIGENBLOCKS = []

for r in range(10, 501, 10):
    U_r = get_first_n_components(u, r)

    x_train_projected = U_r.T @ x_train_centralized
    
    x_test_projected = U_r.T @ x_test_centralized
    
    acertos = 0
    erros = 0
    
    for i in range(GlobalSettings.N_TESTS_USED):
        test_img_proj = x_test_projected[:, i]
        
        distances = np.linalg.norm(x_train_projected.T - test_img_proj, axis=1)
        
        # Find the nearest training sample
        nearest_index = np.argmin(distances)
        
        # Compare the class label of the nearest training sample to the test sample's label
        if y_test[i] == y_train[nearest_index]:
            acertos += 1
        else:
            erros += 1
            
    total = acertos+erros

    ACERTOS.append(acertos)
    ERROS.append(erros)
    TAXA_ACERTOS.append(100*(acertos/total))
    VARIABILIDADE_ACUMULADA.append(calculate_accumulated_variability(s,r))
    EIGENBLOCKS.append(r)

acertos = np.array(ACERTOS)
erros = np.array(ERROS)
taxaAcerto = np.array(TAXA_ACERTOS)
variabilidadeAcumulada = np.array(VARIABILIDADE_ACUMULADA)
num_eigenblocks = np.array(EIGENBLOCKS)

plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada,taxaAcerto,lw=3.0)
plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.show()


plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada, taxaAcerto, lw=3.0, marker='o')

# Add annotations for each point
for x, y, n in zip(variabilidadeAcumulada, taxaAcerto, num_eigenblocks):
    plt.annotate(f'{n}', (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.title("Acurácia vs Variabilidade Acumulada with Eigenblocks")
plt.show()

# %%
ACERTOS = []
ERROS = []
TAXA_ACERTOS = []
VARIABILIDADE_ACUMULADA = []
EIGENBLOCKS = []

for r in range(get_r_number_from_accumulated_variability(30, s), get_r_number_from_accumulated_variability(40, s), 5):
    U_r = get_first_n_components(u, r)

    x_train_projected = U_r.T @ x_train_centralized
    
    x_test_projected = U_r.T @ x_test_centralized
    
    acertos = 0
    erros = 0
    
    for i in range(GlobalSettings.N_TESTS_USED):
        test_img_proj = x_test_projected[:, i]
        
        distances = np.linalg.norm(x_train_projected.T - test_img_proj, axis=1)
        
        # Find the nearest training sample
        nearest_index = np.argmin(distances)
        
        # Compare the class label of the nearest training sample to the test sample's label
        if y_test[i] == y_train[nearest_index]:
            acertos += 1
        else:
            erros += 1
            
    total = acertos+erros

    ACERTOS.append(acertos)
    ERROS.append(erros)
    TAXA_ACERTOS.append(100*(acertos/total))
    VARIABILIDADE_ACUMULADA.append(calculate_accumulated_variability(s,r))
    EIGENBLOCKS.append(r)

acertos = np.array(ACERTOS)
erros = np.array(ERROS)
taxaAcerto = np.array(TAXA_ACERTOS)
variabilidadeAcumulada = np.array(VARIABILIDADE_ACUMULADA)
num_eigenblocks = np.array(EIGENBLOCKS)

plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada,taxaAcerto,lw=3.0)
plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.show()


plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada, taxaAcerto, lw=3.0, marker='o')

# Add annotations for each point
for x, y, n in zip(variabilidadeAcumulada, taxaAcerto, num_eigenblocks):
    plt.annotate(f'{n}', (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.title("Acurácia vs Variabilidade Acumulada with Eigenblocks")
plt.show()

# %%
ACERTOS = []
ERROS = []
TAXA_ACERTOS = []
VARIABILIDADE_ACUMULADA = []
EIGENBLOCKS = []

for r in range(get_r_number_from_accumulated_variability(32, s), get_r_number_from_accumulated_variability(36, s), 1):
    U_r = get_first_n_components(u, r)

    x_train_projected = U_r.T @ x_train_centralized
    
    x_test_projected = U_r.T @ x_test_centralized
    
    acertos = 0
    erros = 0
    
    for i in range(GlobalSettings.N_TESTS_USED):
        test_img_proj = x_test_projected[:, i]
        
        distances = np.linalg.norm(x_train_projected.T - test_img_proj, axis=1)
        
        # Find the nearest training sample
        nearest_index = np.argmin(distances)
        
        # Compare the class label of the nearest training sample to the test sample's label
        if y_test[i] == y_train[nearest_index]:
            acertos += 1
        else:
            erros += 1
            
    total = acertos+erros

    ACERTOS.append(acertos)
    ERROS.append(erros)
    TAXA_ACERTOS.append(100*(acertos/total))
    VARIABILIDADE_ACUMULADA.append(calculate_accumulated_variability(s,r))
    EIGENBLOCKS.append(r)

acertos = np.array(ACERTOS)
erros = np.array(ERROS)
taxaAcerto = np.array(TAXA_ACERTOS)
variabilidadeAcumulada = np.array(VARIABILIDADE_ACUMULADA)
num_eigenblocks = np.array(EIGENBLOCKS)

plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada,taxaAcerto,lw=3.0)
plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.show()


plt.figure(figsize=(8,5))
plt.plot(variabilidadeAcumulada, taxaAcerto, lw=3.0, marker='o')

# Add annotations for each point
for x, y, n in zip(variabilidadeAcumulada, taxaAcerto, num_eigenblocks):
    plt.annotate(f'{n}', (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.grid()
plt.ylabel("Acurácia (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.title("Acurácia vs Variabilidade Acumulada with Eigenblocks")
plt.show()

# %%
perform_multiple_runs_to_create_graph(20, 30, 1)

# %%
perform_multiple_runs_to_create_graph(26, 38, 1)

# %%
perform_multiple_runs_to_create_graph(15, 40, 1)
